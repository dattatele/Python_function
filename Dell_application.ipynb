# %%
import dash
from dash.dependencies import Input, Output, State
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly
import json


from pandas_datareader import data as web
from datetime import datetime as db
import dash_table_experiments as dt


combine_df = pd.read_excel('Dell_Data.xlsx')
price_df = combine_df.set_index('Year')


app = dash.Dash('Dell')
app.css.append_css({
    "external_url": "https://codepen.io/chriddyp/pen/bWLwgP.css"
})

# Dropdown

app.layout = html.Div([
    html.Div(html.H3('DELL',style={'textAlign': 'center', 'color': '#fcfcfc','verticalAlign':'middle'}),
              style={'background-color': '#4286f4'}),
                       html.Div([html.P('Select dropdown list'),
                       dcc.Dropdown(
                           id='my-dropdown',
                           options=[
                               {'label': 'Net Revenue in billion US Dollars',
                                'value': 'Net Revenue in billion US Dollars'},
                               {'label': 'Number of Employees',
                                'value': 'Number of Employees'}
                           ],
                           value = 'Net Revenue in billion US Dollars'
                       ),
                       dcc.Graph(id='my-graph')
                      ], style={'width': '90%'}),
                       
                       html.Div([
                           html.Div([html.H3('Current Market Watch'),
                                     html.Iframe(src="https://www.marketwatch.com/investing/stock/dvmt", height="400", width="100%")],
                                    style={'width': '50%','float': 'right','display': 'inline-block'})
]),
    
    html.Div([dcc.Markdown('''
## Facts    

[Dell URL](https://dell.com).

-**Number of small and medium-sized businesses Dell serves:** [over 10 million](https://www.delltechnologies.com/en-us/annual-report/2017/index.htm)

-**Number of annual ecommerce visits to Dell:** [500 million](https://www.delltechnologies.com/en-us/annual-report/2017/index.htm)

-**Average number of daily ecommerce visits to Dell:** [1.4 million](https://www.delltechnologies.com/en-us/annual-report/2017/index.htm)

-**Percentage of the global Fortune 500 that are tech partners with Dell:** [98%](https://www.delltechnologies.com/en-us/annual-report/2017/index.htm)

-**Number of people served by Dell's cloud:** [1 billion](https://www.delltechnologies.com/en-us/annual-report/2017/index.htm)

-**Average number of cyber attacks that are processed daily by Dell Secureworks:** [160 billion](https://www.delltechnologies.com/en-us/annual-report/2017/index.htm)

-**Number of Dell research and developemnt centers globally:** [14](https://www.delltechnologies.com/en-us/annual-report/2017/index.htm)

-**Amount Dell spent on R&D in FY 2017:** [$2.6 billion](https://www.delltechnologies.com/en-us/annual-report/2017/index.htm)

-**Total number of Dell patents:** [13289](https://www.delltechnologies.com/en-us/annual-report/2017/index.htm)

-**Percentage of Dell employess that are located in the US:** [40%](https://www.delltechnologies.com/en-us/annual-report/2017/index.htm)
''')],
        style={'width': '45%','padding': '2.5rem','float': 'left', 'display': 'inline-block'}),
    
    
    html.Div([html.Iframe(src="https://dattatele.github.io/url_data/oil_cluster.html", width="100%", height="300")]),
    html.Div([html.Iframe(src="https://dattatele.github.io/hospitals.html", width="100%", height="300")]),
    dcc.Markdown(
   <div class='tableauPlaceholder' id='viz1519365493636' style='position: relative'><noscript><a href='#'>
   <img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ho&#47;HospitalswithMedicare&#47; Dashboard1&#47;1_rss.png' style='border: none' /></a>
   </noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> 
   <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='HospitalswithMedicare&#47;Dashboard1' />
   <param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ho&#47;HospitalswithMedicare&#47;Dashboard1&#47;1.png' /> 
   <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' />
   <param name='filter' value='publish=yes' /></object></div> <script type='text/javascript'> var divElement = document.getElementById('viz1519365493636'); var vizElement = divElement.getElementsByTagName('object')[0]; vizElement.style.width='1000px';vizElement.style.height='827px'; var scriptElement = document.createElement('script'); scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js'; vizElement.parentNode.insertBefore(scriptElement, vizElement); </script> 
    )

])
                       
@app.callback(Output('my-graph', 'figure'), [Input('my-dropdown', 'value')])
def update_graph(selected_dropdown_value):
    sales_dff = price_df[selected_dropdown_value]
    return {
        'data': [{
            'x': price_df.index,
            'y': sales_dff
        }],
        'layout': {'margin': {'l': 40, 'r': 0, 't': 20, 'b': 30}}
    }

#app.css.append_css({'external_url': 'https://codepen.io/chriddyp/pen/bWLwgP.css'})

dash.Dash(csrf_protect=False)

if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
#   File "<ipython-input-9-826eb0a9ba38>", line 80
#     <div class='tableauPlaceholder' id='viz1519365493636' style='position: relative'><noscript><a href='#'>
#     ^
# SyntaxError: invalid syntax

# %%
import dash
from dash.dependencies import Input, Output, State
import dash_core_components as dcc
import dash_html_components as html
import dash_table_experiments as dt
import json
import pandas as pd
import numpy as np
import plotly

app = dash.Dash()

#app.scripts.config.serve_locally = True
# app.css.config.serve_locally = True

DF_GAPMINDER = pd.read_csv(
    'https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv'
)
#DF_GAPMINDER = DF_GAPMINDER[DF_GAPMINDER['year'] == 2007]
DF_GAPMINDER.loc[0:20]

DF_SIMPLE = pd.DataFrame({
    'x': ['A', 'B', 'C', 'D', 'E', 'F'],
    'y': [4, 3, 1, 2, 3, 6],
    'z': ['a', 'b', 'c', 'a', 'b', 'c']
})

ROWS = [
    {'a': 'AA', 'b': 1},
    {'a': 'AB', 'b': 2},
    {'a': 'BB', 'b': 3},
    {'a': 'BC', 'b': 4},
    {'a': 'CC', 'b': 5},
    {'a': 'CD', 'b': 6}
]


app.layout = html.Div([
    html.H4('Gapminder DataTable'),
    dt.DataTable(
        rows=DF_GAPMINDER.to_dict('records'),

        # optional - sets the order of columns
        columns=sorted(DF_GAPMINDER.columns),

        row_selectable=True,
        filterable=True,
        sortable=True,
        selected_row_indices=[],
        id='datatable-gapminder'
    ),
    html.Div(id='selected-indexes'),
    dcc.Graph(
        id='graph-gapminder'
    ),
], className="container")


@app.callback(
    Output('datatable-gapminder', 'selected_row_indices'),
    [Input('graph-gapminder', 'clickData')],
    [State('datatable-gapminder', 'selected_row_indices')])
def update_selected_row_indices(clickData, selected_row_indices):
    if clickData:
        for point in clickData['points']:
            if point['pointNumber'] in selected_row_indices:
                selected_row_indices.remove(point['pointNumber'])
            else:
                selected_row_indices.append(point['pointNumber'])
    return selected_row_indices


@app.callback(
    Output('graph-gapminder', 'figure'),
    [Input('datatable-gapminder', 'rows'),
     Input('datatable-gapminder', 'selected_row_indices')])
def update_figure(rows, selected_row_indices):
    dff = pd.DataFrame(rows)
    fig = plotly.tools.make_subplots(
        rows=3, cols=1,
        subplot_titles=('Life Expectancy', 'GDP Per Capita', 'Population',),
        shared_xaxes=True)
    marker = {'color': ['#0074D9']*len(dff)}
    for i in (selected_row_indices or []):
        marker['color'][i] = '#FF851B'
    fig.append_trace({
        'x': dff['country'],
        'y': dff['lifeExp'],
        'type': 'bar',
        'marker': marker
    }, 1, 1)
    fig.append_trace({
        'x': dff['country'],
        'y': dff['gdpPercap'],
        'type': 'bar',
        'marker': marker
    }, 2, 1)
    fig.append_trace({
        'x': dff['country'],
        'y': dff['pop'],
        'type': 'bar',
        'marker': marker
    }, 3, 1)
    fig['layout']['showlegend'] = False
    fig['layout']['height'] = 800
    fig['layout']['margin'] = {
        'l': 40,
        'r': 10,
        't': 60,
        'b': 200
    }
    fig['layout']['yaxis3']['type'] = 'log'
    return fig


app.css.append_css({
    "external_url": "https://codepen.io/chriddyp/pen/bWLwgP.css"
})

if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/Feb/2018 08:35:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Feb/2018 08:35:45] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Feb/2018 08:35:45] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Feb/2018 08:35:45] "GET /favicon.ico HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Feb/2018 08:35:45] "POST /_dash-update-component HTTP/1.1" 403 -
# 127.0.0.1 - - [23/Feb/2018 08:36:19] "POST /_dash-update-component HTTP/1.1" 403 -
# 127.0.0.1 - - [23/Feb/2018 08:36:21] "POST /_dash-update-component HTTP/1.1" 403 -
# 127.0.0.1 - - [23/Feb/2018 08:36:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Feb/2018 08:36:31] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Feb/2018 08:36:31] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Feb/2018 08:36:31] "GET /favicon.ico HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Feb/2018 08:36:31] "POST /_dash-update-component HTTP/1.1" 403 -
# ...
